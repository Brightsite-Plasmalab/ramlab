# %%
from ramlab.molecules.CH4 import CH4
import matplotlib.pyplot as plt
import wedme.apply.dev
import numpy as np
from ramlab.simulate import simulate

M = CH4

# Select the 5000 most intense transitions
transitions = M.get_all_transitions()
transitions = transitions.sortby("crosssection", ascending=False)[:5000] 

# Calculate the intensity of the transitions for T=860 K
I_stick = M.get_intensity(transitions, T=3000)
dnu_stick = transitions.vacuum_wavenumber

# Simulate the spectrum with Gaussian and Lorentzian broadening
dnu_sim = np.linspace(dnu_stick.min(), dnu_stick.max(), 500)
I_sim = simulate(dnu_sim, dnu_stick, I_stick, 1, 0, N_bin=10)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 10
#       7 M = CH4
#       9 # Select the 5000 most intense transitions
# ---> 10 transitions = M.get_all_transitions()
#      11 transitions = transitions.sortby("crosssection", ascending=False)[:5000]
#      13 # Calculate the intensity of the transitions for T=860 K
#
# File ~/Projects/study/UM/ramlab/src/ramlab/molecules/hitran_linelist_molecule.py:47, in LineListMolecule.get_all_transitions(cls, laser_wavelength, force_recalculate, polarisation)
#      39 """Returns all possible transitions for the molecule.
#      40
#      41 Returns:
#      42     Transitions: The transitions.
#      43 """
#      45 if not force_recalculate and cls._has_linelist_file(laser_wavelength):
#      46     df: pd.DataFrame = parse_hitran_data(
# ---> 47         cls.get_linelist_file(laser_wavelength=laser_wavelength, polarisation = polarisation)
#      48     )
#      49     df = cls.process_hitran_data(df)
#      51     return Transitions(df)
#
# TypeError: CH4.get_linelist_file() got an unexpected keyword argument 'polarisation'

# %%
# Plot the results
plt.figure()
plt.vlines(dnu_stick, 0, I_stick / np.nanmax(I_stick), color="k", alpha=0.5, label="Stick spectrum")
plt.plot(dnu_sim, I_sim / np.nanmax(I_sim), color="r", label="Simulated spectrum")
plt.legend()
plt.xlabel(r"Wavenumber [$\mathrm{cm^{-1}}$]")
plt.ylabel(r"Normalized intensity [$\mathrm{\emdash}$]")
plt.title(r"$\mathregular{CH_4}$ spectrum at 860 K")
plt.show()
